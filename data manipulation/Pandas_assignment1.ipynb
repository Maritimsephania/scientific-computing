# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('schools.csv')
data
# Out:
#                                            school_name    borough  \
# 0    New Explorations into Science, Technology and ...  Manhattan
# 1                                 Essex Street Academy  Manhattan
# 2                         Lower Manhattan Arts Academy  Manhattan
# 3      High School for Dual Language and Asian Studies  Manhattan
# 4        Henry Street School for International Studies  Manhattan
# ..                                                 ...        ...
# 370  Queens High School for Information, Research, ...     Queens
# 371  Rockaway Park High School for Environmental Su...     Queens
# 372                   Channel View School for Research     Queens
# 373                    Rockaway Collegiate High School     Queens
# 374                                  Scholars' Academy     Queens
#
#     building_code  average_math  average_reading  average_writing  \
# 0            M022           657              601              601
# ...

# %%
data.describe()
# Out:
#        average_math  average_reading  average_writing  percent_tested
# count    375.000000       375.000000       375.000000      355.000000
# mean     432.944000       424.504000       418.458667       64.976338
# std       71.952373        61.881069        64.548599       18.747634
# min      317.000000       302.000000       284.000000       18.500000
# 25%      386.000000       386.000000       382.000000       50.950000
# 50%      415.000000       413.000000       403.000000       64.800000
# 75%      458.500000       445.000000       437.500000       79.600000
# max      754.000000       697.000000       693.000000      100.000000

# %%
data.head(5)
# Out:
#                                          school_name    borough building_code  \
# 0  New Explorations into Science, Technology and ...  Manhattan          M022
# 1                               Essex Street Academy  Manhattan          M445
# 2                       Lower Manhattan Arts Academy  Manhattan          M445
# 3    High School for Dual Language and Asian Studies  Manhattan          M445
# 4      Henry Street School for International Studies  Manhattan          M056
#
#    average_math  average_reading  average_writing  percent_tested
# 0           657              601              601             NaN
# 1           395              411              387            78.9
# 2           418              428              415            65.1
# 3           613              453              463            95.9
# 4           410              406              381            59.7

# %%
data.describe()
# Out:
#        average_math  average_reading  average_writing  percent_tested
# count    375.000000       375.000000       375.000000      355.000000
# mean     432.944000       424.504000       418.458667       64.976338
# std       71.952373        61.881069        64.548599       18.747634
# min      317.000000       302.000000       284.000000       18.500000
# 25%      386.000000       386.000000       382.000000       50.950000
# 50%      415.000000       413.000000       403.000000       64.800000
# 75%      458.500000       445.000000       437.500000       79.600000
# max      754.000000       697.000000       693.000000      100.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   school_name      375 non-null    object
#  1   borough          375 non-null    object
#  2   building_code    375 non-null    object
#  3   average_math     375 non-null    int64
#  4   average_reading  375 non-null    int64
#  5   average_writing  375 non-null    int64
#  6   percent_tested   355 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 20.6+ KB

# %%
data.sample(5)
# Out:
#                                      school_name    borough building_code  \
# 78                    Frederick Douglass Academy  Manhattan          M010
# 258      El Puente Academy for Peace and Justice   Brooklyn          K778
# 48                            Beacon High School  Manhattan          M837
# 331      Robert F. Kennedy Community High School     Queens          Q707
# 142  Bronx Studio School for Writers and Artists      Bronx          X392
#
#      average_math  average_reading  average_writing  percent_tested
# 78            463              452              450            65.1
# 258           344              380              379            62.5
# 48            583              586              595            82.8
# 331           460              426              423            67.3
# 142           417              412              403            71.6

# %%
data.isnull().sum()
# Out:
# school_name         0
# borough             0
# building_code       0
# average_math        0
# average_reading     0
# average_writing     0
# percent_tested     20
# dtype: int64

# %%
# Aggregate average scores by borough
avg_scores = data.groupby('borough')[['average_math', 'average_reading', 'average_writing']].mean()
avg_scores
# Out:
#                average_math  average_reading  average_writing
# borough
# Bronx            404.357143       402.520408       395.846939
# Brooklyn         416.403670       410.761468       403.091743
# Manhattan        455.887640       444.932584       439.314607
# Queens           462.362319       443.260870       439.855072
# Staten Island    486.200000       478.500000       474.300000

# %%
# Plotting
avg_scores.plot(kind='bar', figsize=(10, 6), width=0.8)

# Customize the chart
plt.title('Average Scores by Borough', fontsize=14)
plt.xlabel('borough', fontsize=12)
plt.ylabel('Average Score', fontsize=12)
plt.legend(title='Score Type')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %%
average_tested = data.groupby('borough')[['percent_tested']].mean()
average_tested
# Out:
#                percent_tested
# borough
# Bronx               58.653763
# Brooklyn            62.640385
# Manhattan           71.390476
# Queens              69.313846
# Staten Island       66.111111

# %%
# Plotting
average_tested.plot(kind='bar', figsize=(10, 6), width=0.8)

# Customize the chart
plt.title('Average Scores by Borough', fontsize=14)
plt.xlabel('borough', fontsize=12)
plt.ylabel('average_tested', fontsize=12)
plt.legend(title='Score Type')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %%
data.plot(kind='scatter', x='average_writing', y='average_math', figsize=(10, 6))
plt.title('Average Math Scores vs. average_writing Scores', fontsize=14)
plt.xlabel('average_writing', fontsize=12)
plt.ylabel('average_math', fontsize=12)
plt.grid(True)
plt.show()

# %%
data[['average_writing', 'average_reading']].plot(kind='hist', bins=10, alpha=0.6, figsize=(10, 6), legend=True)
plt.title('Distribution of Average Writing and Reading Scores')
plt.xlabel('Score')
plt.ylabel('Number of Schools')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#compute the correlation matrix
corr = data[['average_math', 'average_reading', 'average_writing']].corr()  
corr
# Out:
#                  average_math  average_reading  average_writing
# average_math         1.000000         0.928239         0.934155
# average_reading      0.928239         1.000000         0.985439
# average_writing      0.934155         0.985439         1.000000

# %%
#plot the correlation matrix
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                                            school_name    borough  \
# 0    New Explorations into Science, Technology and ...  Manhattan
# 1                                 Essex Street Academy  Manhattan
# 2                         Lower Manhattan Arts Academy  Manhattan
# 3      High School for Dual Language and Asian Studies  Manhattan
# 4        Henry Street School for International Studies  Manhattan
# ..                                                 ...        ...
# 370  Queens High School for Information, Research, ...     Queens
# 371  Rockaway Park High School for Environmental Su...     Queens
# 372                   Channel View School for Research     Queens
# 373                    Rockaway Collegiate High School     Queens
# 374                                  Scholars' Academy     Queens
#
#     building_code  average_math  average_reading  average_writing  \
# 0            M022           657              601              601
# ...

# %%
data.isnull().sum()
# Out:
# school_name         0
# borough             0
# building_code       0
# average_math        0
# average_reading     0
# average_writing     0
# percent_tested     20
# dtype: int64

# %%
data['percent_tested'].fillna(data['percent_tested'].mean())
# Out:
# 0      64.976338
# 1      78.900000
# 2      65.100000
# 3      95.900000
# 4      59.700000
#          ...
# 370    44.600000
# 371    38.500000
# 372    76.600000
# 373    46.500000
# 374    99.200000
# Name: percent_tested, Length: 375, dtype: float64

# %%
data.isnull().sum()
# Out:
# school_name         0
# borough             0
# building_code       0
# average_math        0
# average_reading     0
# average_writing     0
# percent_tested     20
# dtype: int64
